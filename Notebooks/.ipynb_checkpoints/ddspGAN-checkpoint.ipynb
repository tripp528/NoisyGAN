# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %cd ..
# !ls
from core import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Data        README.md   core        models      submit.sh
# Notebooks   __init__.py depricated  notes_ideas train.py

# %% [markdown]
# Similar to mnist GAN,
#
# mnist was a dataset of shape (n, 28, 28)
#
# ddsp is a dataset of shape (n, 64000)

# %% [markdown]
# #### Discriminator will be
#
# input shape (64000)
#
# encode into latent space (?)
#
# output shape (1)

# %%
# get a dataset
output_tfrecord_path = './Data/piano/piano30s.tfrecord'
dataset = DDSP_DATASET(output_tfrecord_path)

# get a sample
i = 0
real_sample = dataset.getSample(sampleNum=i)
describeSample(real_sample)
# Out:
# audio: (64000,) Range: -0.24915089 0.28982782
# f0_confidence: (1000,) Range: 0.019729322 0.9687585
# f0_hz: (1000,) Range: 41.480316 783.93646
# loudness_db: (1000,) Range: -84.711914 -58.525723

# %%
# first get into f0_scaled and ld_scaled 
preprocessor = ddsp.training.preprocessing.DefaultPreprocessor(time_steps=1000)
preprocessed = preprocessor(real_sample, training=True)
describeSample(preprocessed)
# Out:
# audio: (64000,) Range: -0.24915089 0.28982782
# f0_confidence: (1000,) Range: 0.019729322 0.9687585
# f0_hz: (1, 1000, 1) Range: 41.480316 783.93646
# loudness_db: (1, 1000, 1) Range: -84.711914 -58.525723
# f0_scaled: (1, 1000, 1) Range: 0.22138539 0.6220379
# ld_scaled: (1, 1000, 1) Range: 0.29406738 0.51228565

# %%
# get z :::TODO we aren't generating z to get sample......
f0_encoder = ddsp.training.encoders.ResnetF0Encoder()
encoder = ddsp.training.encoders.MfccTimeDistributedRnnEncoder(z_dims=4,
                                                               z_time_steps=1000,
                                                               f0_encoder=f0_encoder)
encoder(preprocessed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-a3c88b68460f> in <module>
#       2 encoder = ddsp.training.encoders.MfccTimeDistributedRnnEncoder(z_dims=4,
#       3                                                                z_time_steps=1000,
# ----> 4                                                                f0_encoder=ResnetF0Encoder())
#       5 encoder(preprocessed)
#
# NameError: name 'ResnetF0Encoder' is not defined

# %%
from ddsp.spectral_ops import compute_mfcc
compute_mfcc(preprocessed['audio']).shape
# Out:
# TensorShape([250, 13])

# %% [markdown]
# #### Generator
#
# input shape (100)
#
# upsample into (f0_scaled, ld_scaled) (2x1000)
#
# run through decoder & processor group
#
# output shape (64000)

# %%
from tensorflow.keras.utils import plot_model

# %%
generator = Generator(latent_dim=100)
fake_sample = generator.generate()
describeSample(fake_sample)
play(fake_sample['audio'])
# Out:
# # params:  1287084
#
# f0_scaled: (1, 1000, 1) Range: 0.493731 0.5167515
# ld_scaled: (1, 1000, 1) Range: 0.48756102 0.51191294
# f0_hz: (1, 1000, 1) Range: 305.84976 362.11728
# loudness_db: (1, 1000, 1) Range: -61.492683 -58.570446
# amps: (1, 1000, 1) Range: -0.3735244 0.025014732
# harmonic_distribution: (1, 1000, 45) Range: -1.7450904 2.3414545
# noise_magnitudes: (1, 1000, 45) Range: -1.3944162 2.2605267
# audio: (64000,) Range: -0.286338 0.28594485
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
