# %%
# %load_ext autoreload
# %cd ..
# Out:
# /Users/trippgordon/Desktop/Code/sonic/NoisyGAN

# %%
# %autoreload 2
# %reload_ext autoreload
# %pwd
from core import *
import gin
gin.enter_interactive_mode()

# %%
batch_size = 8

# data_provider = FromTFRecords('./Data/test/acapella.tfrecord*')
data_provider = FromTFRecords('./Data/piano/piano30s.tfrecord*')
gan_model = GAN(Generator(latent_dim=100), Discriminator(batch_size=batch_size))
combined_iter = combined_sample_iter(gan_model.gen, data_provider, batch_size=batch_size)
opt = tf.keras.optimizers.Adam()

# %%
train_gan(gan_model, opt, combined_iter, model_dir="models/gan/", total_iters=1)
# Out:
# INFO:absl:----- GAN Step 0 -----
# INFO:absl:generating... batch 6

# %%
play(gan_model.gen.generate()['audio'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
df = pd.DataFrame({"disc": [], "gen": []})
df.append({"disc": '3', "gen": '4'}, ignore_index=True,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b08dc48ad4f3> in <module>
#       1 df = pd.DataFrame({"disc": [], "gen": []})
# ----> 2 df.append({"disc": '3', "gen": '4'}, ignore_index=True,inplace=True)
#       3 df
#
# TypeError: append() got an unexpected keyword argument 'inplace'
