# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %cd ..
# !ls
from core import *
# Out:
# /Users/trippgordon/Desktop/Code/sonic/NoisyGAN
# Data        README.md   core        models      submit.sh
# Notebooks   __init__.py depricated  notes_ideas train.py
# INFO:absl:tf versionn: 2.1.0

# %% [markdown]
# Similar to mnist GAN,
#
# mnist was a dataset of shape (n, 28, 28)
#
# ddsp is a dataset of shape (n, 64000)

# %% [markdown]
# #### Discriminator will be
#
# input shape (64000)
#
# encode into latent space (6 x 1000)
#
# - f0_scaled (1 x 1000)
# - ld_scaled (1 x 1000)
# - z (4 x 1000)
#
# output shape (1)

# %%
batch_size=2
real_dataset = DDSP_DATASET('./Data/piano/piano30s.tfrecord', generator=generator)
# real_dataset.data_provider.get_batch(batch_size, shuffle=True, repeats=-1)
describeSample(real_dataset.getSample())
# Out:
# INFO:absl:tf versionn: 2.1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c54918c83002> in <module>
#       1 batch_size=2
#       2 real_dataset = DDSP_DATASET('./Data/piano/piano30s.tfrecord', generator=generator)
# ----> 3 real_dataset.data_provider.get_batch(batch_size, shuffle=True, repeats=-1)
#       4 # describeSample(real_dataset.getSample())
#
# ~/Desktop/Code/sonic/NoisyGAN/core/ddsp_dataset.py in get_batch(self, batch_size, shuffle, repeats)
#     105         # return true_dataset
#     106
# --> 107         fake_dataset = self.get_fake_dataset()
#     108         fake_dataset = fake_dataset.repeat(repeats)
#     109         fake_dataset = fake_dataset.batch(int(batch_size/2), drop_remainder=True)
#
# ~/Desktop/Code/sonic/NoisyGAN/core/ddsp_dataset.py in get_fake_dataset(self, size)
#     147             yield self.generator.generate(label=0)
# ...

# %%
trainer = DDSP_TRAINER(model_dir="./models/disc/",
                       model_type="discriminator",
                       batch_size=batch_size)
# Out:
# INFO:absl:MODEL_DIR: ./models/disc/ FOUND: False
# INFO:absl:Defaulting to MirroredStrategy
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)

# %%
trainer.train(dataset, iterations=10)
# Out:
# Model: "discriminator"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# binary_crossentropy (binary_ multiple                  0
# _________________________________________________________________
# mfcc_time_distrbuted_rnn_enc multiple                  838722
# _________________________________________________________________
# sequential_6 (Sequential)    (8, 1)                    6993
# ...
# Total params: 845,715
# Trainable params: 845,619
# Non-trainable params: 96
# _________________________________________________________________
# INFO:absl:Step:1 Loss:7.36
# INFO:absl:Step:2 Loss:5.94
# INFO:absl:Step:3 Loss:4.72
# INFO:absl:Step:4 Loss:2.14
# INFO:absl:Step:5 Loss:0.50
# INFO:absl:Step:6 Loss:0.38
# INFO:absl:Step:7 Loss:0.19
# INFO:absl:Step:8 Loss:0.07
# INFO:absl:Step:9 Loss:0.04
# INFO:absl:Step:10 Loss:0.03
# INFO:absl:Saved checkpoint to ./models/disc/ at step 10
# ...

# %% [markdown]
# #### Generator
#
# input shape (100)
#
# upsample into (f0_scaled, ld_scaled) (2x1000)
#
# run through decoder & processor group
#
# output shape (64000)

# %%
from tensorflow.keras.utils import plot_model

# %%
generator = Generator(latent_dim=100)
fake_sample = generator.generate(label=0)
describeSample(fake_sample)
play(fake_sample['audio'])
# Out:
# # params:  1276365
#
# f0_scaled: (1, 1000, 1)
# ld_scaled: (1, 1000, 1)
# z: (1, 1000, 6)
# f0_hz: (1, 1000, 1)
# loudness_db: (1, 1000, 1)
# amps: (1, 1000, 1)
# harmonic_distribution: (1, 1000, 45)
# noise_magnitudes: (1, 1000, 45)
# audio: (1, 64000)
# label: (1,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
