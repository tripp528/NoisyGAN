# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %cd ..
# !ls
from core import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Data        README.md   core        models      submit.sh
# Notebooks   __init__.py depricated  notes_ideas train.py

# %% [markdown]
# #### Generator
#
# input shape (100)
#
# upsample into (f0_scaled, ld_scaled) (2x1000)
#
# run through decoder & processor group
#
# output shape (64000)

# %%
gen = Generator(latent_dim=100)
fake_sample = gen.generate(label=0)
describeSample(fake_sample)
play(fake_sample['audio'])
# Out:
# # params:  1276365
#
# audio: (64000,)
# f0_hz: (1000,)
# loudness_db: (1000,)
# label: (1,)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### Get alternating batches
#
# Maybe getting combined batches would be better...

# %%
# def fake_sample_generator(gen, batch_size=8):
#     shapes = {"f0_hz": (1000,),
#                     "loudness_db": (1000,),
#                     "audio": (64000,),
#                     "label": (1,)}
    
#     i = -1
#     while True:
#         i+=1
#         logging.info("generating... batch "+str(i))
#         generated = gen.generate_batch(label=0,batch_size=batch_size)
#         batch = {}
#         for key in shapes:
#             batch[key] = generated[key]

#         yield batch
        
# def imerge(a, b):
#     for i, j in zip(a,b):
#         yield i
#         yield j
        
def combined_sample_generator(gen, dataset, batch_size=8):
    half_batch = int(batch_size/2)
    shapes = {"f0_hz": (1000,),
                    "loudness_db": (1000,),
                    "audio": (64000,),
                    "label": (1,)}
    
    i = -1
    while True:
        i+=1
        logging.info("generating... batch "+str(i))
        generated = gen.generate_batch(label=0,batch_size=half_batch)
        real = next(iter(dataset.data_provider.get_batch(half_batch, shuffle=True, repeats=-1)))
        batch = {}
        for key in shapes:
            batch[key] = tf.concat([generated[key],real[key]],axis=0)

        yield batch

# %%
combined_iter = iter(combined_sample_generator(gen, dataset, batch_size=8))
describeSample(next(combined_iter))
# Out:
# INFO:absl:generating... batch 0
# f0_hz: (8, 1000)
# loudness_db: (8, 1000)
# audio: (8, 64000)
# label: (8, 1)

# %% [markdown]
# #### Discriminator
#
# input shape (64000)
#
# encode into latent space (6 x 1000)
#
# - f0_scaled (1 x 1000)
# - ld_scaled (1 x 1000)
# - z (4 x 1000)
#
# output shape (1)

# %%
def train_discriminator_loop(discriminator, opt, dataset_iter, iters=10):
    for i in range(iters):
        batch = next(dataset_iter)
        # train_step
        grad_clip_norm = 3.0
        with tf.GradientTape() as tape:
            _ = discriminator(batch,training=True)
            total_loss = tf.reduce_sum(discriminator.losses)
            print("Step " + str(i) + "Loss: " + str(total_loss))
        grads = tape.gradient(total_loss, discriminator.trainable_variables)
        grads, _ = tf.clip_by_global_norm(grads, grad_clip_norm)
        opt.apply_gradients(zip(grads, discriminator.trainable_variables))

# %%
batch_size = 8

# fake
gen = Generator(latent_dim=100)
gen_iter = iter(fake_sample_generator(gen,batch_size=batch_size))
#real
dataset = DDSP_DATASET('./Data/piano/piano30s.tfrecord')
real_iter = iter(dataset.data_provider.get_batch(batch_size, shuffle=True, repeats=-1))
# alternate batches
combined_iter = imerge(gen_iter,real_iter)
# discriminate
discriminator = Discriminator(batch_size=batch_size)
opt = tf.keras.optimizers.Adam()
# Out:
# # params:  1276365

# %%
# predict a batch of real and a batch of fake
batch1 = next(combined_iter)
batch2 = next(combined_iter)
print(discriminator(batch1), batch1['label'])
print(discriminator(batch2), batch2['label'])
# Out:
# INFO:absl:generating... batch 6
# tf.Tensor(
# [[0.00095372]
#  [0.00170901]
#  [0.00275367]
#  [0.00156411]
#  [0.00169572]
#  [0.00160699]
#  [0.00153972]
#  [0.00447009]], shape=(8, 1), dtype=float32) tf.Tensor(
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]], shape=(8, 1), dtype=float32)
# tf.Tensor(
# [[0.85388213]
#  [0.9259345 ]
#  [0.6860682 ]
#  [0.92091024]
#  [0.7495889 ]
#  [0.79706025]
#  [0.90145594]
#  [0.79982793]], shape=(8, 1), dtype=float32) tf.Tensor(
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]], shape=(8, 1), dtype=float32)

# %%
train_discriminator_loop(discriminator, opt, combined_iter, iters=10)
# Out:
# INFO:absl:generating... batch 0
# Step 0Loss: tf.Tensor(7.1235104, shape=(), dtype=float32)
# Step 1Loss: tf.Tensor(9.249603, shape=(), dtype=float32)
# INFO:absl:generating... batch 1
# Step 2Loss: tf.Tensor(0.21602878, shape=(), dtype=float32)
# Step 3Loss: tf.Tensor(6.6578045, shape=(), dtype=float32)
# INFO:absl:generating... batch 2
# Step 4Loss: tf.Tensor(0.14748952, shape=(), dtype=float32)
# Step 5Loss: tf.Tensor(6.918948, shape=(), dtype=float32)
# INFO:absl:generating... batch 3
# Step 6Loss: tf.Tensor(0.022178546, shape=(), dtype=float32)
# Step 7Loss: tf.Tensor(1.9070501, shape=(), dtype=float32)
# INFO:absl:generating... batch 4
# Step 8Loss: tf.Tensor(0.059767555, shape=(), dtype=float32)
# Step 9Loss: tf.Tensor(2.0270712, shape=(), dtype=float32)
