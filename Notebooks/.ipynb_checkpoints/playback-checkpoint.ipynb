# %%
import sys
from importlib import reload

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

sys.path.append("..")
from core.ddsp_trainer import *
# Out:
# tf versionn:  2.1.0

# %%
# gpu limit
# on_linux_box = True
# if on_linux_box:
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4624)])

# %%
# load model, make prediction
autoencoder = DDSP_AUTOENCODER2('./Data/piano/piano30s.tfrecord', model_dir="./models/auto_2/", restore=True)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# WARNING:tensorflow:From /home/tripp/miniconda3/envs/ddsp2/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/tripp/miniconda3/envs/ddsp2/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "autoencoder2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spectral_loss (SpectralLoss) multiple                  0
# _________________________________________________________________
# rnn_fc_decoder (RnnFcDecoder multiple                  814171
# _________________________________________________________________
# processor_group (ProcessorGr multiple                  48000
# =================================================================
# Total params: 862,171
# Trainable params: 862,171
# Non-trainable params: 0
# _________________________________________________________________
# found ./models/auto_2/

# %%
audio, audio_gen = autoencoder.predict(sampleNum=3)
play(audio_gen)
# Out:
# Prediction took 1.4 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
