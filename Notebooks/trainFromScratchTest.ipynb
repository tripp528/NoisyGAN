# %%
import sys
from importlib import reload

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

sys.path.append("..")
from core.ddsp_trainer import *
# Out:
# INFO:absl:tf versionn: 2.1.0

# %%
# gpu limit
# gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4624)])

# %% [markdown]
# ### load dataset

# %%
# build dataset (include input_audio_filepattern if you haven't made tfrecords yet)
# input_audio_filepattern = "./Data/piano/piano30s.wav"
output_tfrecord_path = '../Data/piano/piano30s.tfrecord'
dataset = DDSP_DATASET(output_tfrecord_path)

# play a sample
play(dataset.getAudio())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### build model

# %%
model_dir = "../models/auto/"
autoencoder = DDSP_TRAINER(model_dir)
# Out:
# INFO:absl:found ../models/auto/
# INFO:absl:Defaulting to MirroredStrategy
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:absl:restoring... ../models/auto/ckpt-130
# INFO:absl:Loaded checkpoint ../models/auto/ckpt-130
# INFO:absl:Loading model took 0.0 seconds

# %%
# train
autoencoder.train(dataset,iterations=2)
#predict
audio, audio_gen = autoencoder.predict(dataset,sampleNum=3)
play(audio_gen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ef938236bbd> in <module>
#       1 # train
# ----> 2 autoencoder.train(dataset,iterations=2)
#       3 #predict
#       4 audio, audio_gen = autoencoder.predict(dataset,sampleNum=3)
#       5 play(audio_gen)
#
# NameError: name 'autoencoder' is not defined
