# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %cd ..
# !ls
from core import *
# Out:
# /Users/trippgordon/Desktop/Code/sonic/NoisyGAN
# Data        README.md   core        models      submit.sh
# Notebooks   __init__.py depricated  notes_ideas train.py
# INFO:absl:tf versionn: 2.1.0

# %%
# gpu limit only for linux box!
# gpus = tf.config.experimental.list_physical_devices('GPU')
# tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4624)])

# %% [markdown]
# ### load dataset
# build dataset (include input_audio_filepattern if you haven't made tfrecords yet)

# %%
# input_audio_filepattern = "./Data/piano/piano30s.wav"
output_tfrecord_path = './Data/piano/piano30s.tfrecord'
dataset = DDSP_DATASET(output_tfrecord_path)

# play a sample
play(dataset.getAudio())
# Out:
# INFO:absl:tf versionn: 2.1.0
# {'audio': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:0' shape=(64000,) dtype=float32>, 'f0_confidence': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:1' shape=(1000,) dtype=float32>, 'f0_hz': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:2' shape=(1000,) dtype=float32>, 'loudness_db': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:3' shape=(1000,) dtype=float32>, 'label': 1}
# {'audio': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:0' shape=(64000,) dtype=float32>, 'f0_confidence': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:1' shape=(1000,) dtype=float32>, 'f0_hz': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:2' shape=(1000,) dtype=float32>, 'loudness_db': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:3' shape=(1000,) dtype=float32>, 'label': 1}
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### build model

# %%
model_dir = "./models/gan/"
model = Solo_Autoencoder()
trainer = DDSP_TRAINER(model_dir,model=model)
# Out:
# INFO:absl:tf versionn: 2.1.0
# [autoreload of ddsp.training.train_util failed: Traceback (most recent call last):
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/ddsp/training/train_util.py", line 120, in <module>
#     class Trainer(object):
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/gin/config.py", line 1252, in configurable
#     return perform_decoration(decoration_target)
#   File "/Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/gin/config.py", line 1249, in perform_decoration
#     return _make_configurable(fn_or_cls, name, module, whitelist, blacklist)
# ValueError: A configurable matching 'ddsp.training.train_util.Trainer' already exists.
#
# To allow re-registration of configurables in an interactive environment, use:
#
#     gin.enter_interactive_mode()
# ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-105493232128> in <module>
#       1 model_dir = "./models/gan/"
#       2 model = Solo_Autoencoder()
# ----> 3 trainer = DDSP_TRAINER(model_dir,model=model)
#
# TypeError: __init__() got an unexpected keyword argument 'model'

# %%
# train
trainer.train(dataset,iterations=2)
#predict
audio, audio_gen = trainer.predict(dataset,sampleNum=3)
play(audio_gen)
# Out:
# {'audio': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:0' shape=(64000,) dtype=float32>, 'f0_confidence': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:1' shape=(1000,) dtype=float32>, 'f0_hz': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:2' shape=(1000,) dtype=float32>, 'loudness_db': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:3' shape=(1000,) dtype=float32>, 'label': 1}
# WARNING:tensorflow:From /Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Users/trippgordon/miniconda3/envs/ddsp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:absl:Loaded checkpoint ./models/gan/ckpt-7
# INFO:absl:Loading model took 0.0 seconds
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spectral_loss (SpectralLoss) multiple                  0
# _________________________________________________________________
# rnn_fc_decoder (RnnFcDecoder multiple                  814171
# _________________________________________________________________
# processor_group (ProcessorGr multiple                  48000
# =================================================================
# Total params: 862,171
# Trainable params: 862,171
# Non-trainable params: 0
# _________________________________________________________________
# INFO:absl:Step:8 Loss:16.21
# INFO:absl:Saved checkpoint to ./models/gan/ at step 8
# INFO:absl:Saving model took 0.1 seconds
# INFO:absl:Step:9 Loss:15.14
# INFO:absl:Saved checkpoint to ./models/gan/ at step 9
# INFO:absl:Saving model took 0.1 seconds
# INFO:absl:Training Finished!
# {'audio': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:0' shape=(64000,) dtype=float32>, 'f0_confidence': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:1' shape=(1000,) dtype=float32>, 'f0_hz': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:2' shape=(1000,) dtype=float32>, 'loudness_db': <tf.Tensor 'ParseSingleExample/ParseExample/ParseExampleV2:3' shape=(1000,) dtype=float32>, 'label': 1}
# INFO:absl:Prediction took 1.1 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
