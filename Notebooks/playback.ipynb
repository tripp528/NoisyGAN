# %%
import sys
from importlib import reload

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

sys.path.append("..")
from core.ddsp_trainer import *
# Out:
# INFO:absl:tf versionn: 2.1.0

# %%
# gpu limit
# on_linux_box = True
# if on_linux_box:
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4624)])

# %%
# load dataset
dataset = DDSP_DATASET('../Data/piano/piano30s.tfrecord')
play(dataset.getAudio())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
autoencoder = DDSP_TRAINER("../models/auto/")
# Out:
# INFO:absl:found ../models/auto/
# INFO:absl:Defaulting to MirroredStrategy
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:absl:restoring... ../models/auto/ckpt-130
# INFO:absl:Loaded checkpoint ../models/auto/ckpt-130
# INFO:absl:Loading model took 0.0 seconds

# %%
# make prediction
audio, audio_gen = autoencoder.predict(dataset,sampleNum=3)
play(audio)
play(audio_gen)
# Out:
# INFO:absl:Connecting node (additive):
# INFO:absl:Input 0: amps
# INFO:absl:Input 1: harmonic_distribution
# INFO:absl:Input 2: f0_hz
# INFO:absl:Connecting node (noise):
# INFO:absl:Input 0: noise_magnitudes
# INFO:absl:Connecting node (add):
# INFO:absl:Input 0: noise/signal
# INFO:absl:Input 1: additive/signal
# INFO:absl:Connecting node (reverb):
# INFO:absl:Input 0: add/signal
# INFO:absl:ProcessorGroup output node (reverb)
# INFO:absl:Prediction took 0.9 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
