# %%
import sys
from importlib import reload

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

sys.path.append("..")
from core.ddsp_trainer import *
# Out:
# INFO:absl:tf versionn: 2.1.0

# %%
# gpu limit
# on_linux_box = True
# if on_linux_box:
#     gpus = tf.config.experimental.list_physical_devices('GPU')
#     tf.config.experimental.set_virtual_device_configuration(
#             gpus[0],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4624)])

# %%
# load dataset
dataset = DDSP_DATASET('../Data/piano/piano30s.tfrecord')
play(dataset.getAudio())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
autoencoder = DDSP_TRAINER("../models/auto_2/")
# Out:
# INFO:absl:Defaulting to MirroredStrategy
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-96f7273e9d2e> in <module>
# ----> 1 autoencoder = DDSP_TRAINER("../models/auto_2/")
#
# ~/Desktop/Code/sonic/NoisyGAN/core/ddsp_trainer.py in __init__(self, model_dir, restore, gpus)
#      37         # AUTOMATICALLY restore from checkpoint. If you want to not restore, clear the
#      38         # model dir or set a new model dir.
# ---> 39         self.auto_restore()
#      40
#      41     def buildModel(self):
#
# ~/Desktop/Code/sonic/NoisyGAN/core/ddsp_trainer.py in auto_restore(self)
#      74
#      75     def auto_restore(self):
# ---> 76         ckpt = ddsp.training.train_util.get_latest_chekpoint(self.model_dir)
#      77         logging.info("restoring... "+ckpt)
#      78         self.restore(ckpt)
#
# ~/miniconda3/envs/ddsp/lib/python3.6/site-packages/ddsp/training/train_util.py in get_latest_chekpoint(checkpoint_path)
#      69     Path to latest checkpoint, or None if none exist.
#      70   """
# ---> 71   checkpoint_path = os.path.expanduser(os.path.expandvars(checkpoint_path))
#      72   is_checkpoint = tf.io.gfile.exists(checkpoint_path + '.index')
#      73   if is_checkpoint:
#
# ~/miniconda3/envs/ddsp/lib/python3.6/posixpath.py in expandvars(path)
#     286     """Expand shell variables of form $var and ${var}.  Unknown variables
#     287     are left unchanged."""
# --> 288     path = os.fspath(path)
#     289     global _varprog, _varprogb
#     290     if isinstance(path, bytes):
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
from IPython import display

# %%
# make prediction
audio, audio_gen = autoencoder.predict(sampleNum=3)
play(audio_gen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d945fe103908> in <module>
#       1 # make prediction
# ----> 2 audio, audio_gen = autoencoder.predict(sampleNum=3)
#       3 play(audio_gen)
#
# NameError: name 'autoencoder' is not defined

# %%
play(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
