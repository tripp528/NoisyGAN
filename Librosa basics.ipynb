# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
import librosa
import IPython.display as ipd # for playing audio in jupyter notebook

# %% [markdown]
# ### Load File

# %%
filename = "Data/bassBig.mp3"

# %%
# Load the audio as a waveform `y`
#    Store the sampling rate as `sr`
x, sr = librosa.load(filename)

# plot waveform
librosa.display.waveplot(x)

# player jupyter
ipd.Audio(filename)
# Out:
# /Users/trippgordon/miniconda3/envs/cs254/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Spectrogram

# %%
# short term forier transform
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
