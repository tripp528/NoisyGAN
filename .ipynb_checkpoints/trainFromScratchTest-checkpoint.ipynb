# %%
from importlib import reload

import ddsp_dataset
reload(ddsp_dataset)
from ddsp_dataset import *
# Out:
# tf versionn:  2.1.0
# tf versionn:  2.1.0

# %% [markdown]
# ### load dataset

# %%
# preprocess into tfrecords
input_audio_filepattern = "./Data/piano/piano30s.wav"
output_tfrecord_path = './Data/piano/piano30s.tfrecord'
dataset = DDSP_DATASET(input_audio_filepattern, output_tfrecord_path,buildRecords=False)

# play a sample
play(dataset.getAudio())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### build model

# %%
import ddsp_autoencoder
reload(ddsp_autoencoder)
from ddsp_autoencoder import DDSP_AUTOENCODER

# %%
model_dir = "./models/auto/"
autoencoder = DDSP_AUTOENCODER(dataset, model_dir)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-5-75f2ebcdd445> in <module>
#       1 model_dir = "./models/auto/"
# ----> 2 autoencoder = DDSP_AUTOENCODER(dataset, model_dir=model_dir)
#
# ~/Desktop/Code/sonic/NoisyGAN/ddsp_autoencoder.py in __init__(self, ddsp_dataset, model_dir, restore)
#       5     def __init__(self, ddsp_dataset, model_dir, restore=False):
#       6         self.ddsp_dataset = ddsp_dataset
# ----> 7         self.model_dir = find_model_dir(model_dir)
#       8         # get distribution strategy (change if using gpus/tpus)
#       9         self.strategy = ddsp.training.train_util.get_strategy()
#
# ~/Desktop/Code/sonic/NoisyGAN/my_ddsp_utils.py in find_model_dir(dir_name)
#      62                 print("found", model_dir)
#      63                 break
# ---> 64         return model_dir
#
# UnboundLocalError: local variable 'model_dir' referenced before assignment

# %%
autoencoder.train2(iterations=30)
audio, audio_gen = autoencoder.predict(sampleNum=3)
play(audio_gen)
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spectral_loss (SpectralLoss) multiple                  0
# _________________________________________________________________
# rnn_fc_decoder (RnnFcDecoder multiple                  814171
# _________________________________________________________________
# processor_group (ProcessorGr multiple                  0
# =================================================================
# Total params: 814,171
# Trainable params: 814,171
# Non-trainable params: 0
# _________________________________________________________________
# Prediction took 1.1 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Load in the saved and trained model

# %%
autoencoder2 = DDSP_AUTOENCODER(dataset, model_dir=model_dir)
# play audio before restoring from checkpoint
audio, audio_gen = autoencoder2.predict(sampleNum=3)
play(audio_gen)
# Out:
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# spectral_loss (SpectralLoss) multiple                  0
# _________________________________________________________________
# rnn_fc_decoder (RnnFcDecoder multiple                  814171
# _________________________________________________________________
# processor_group (ProcessorGr multiple                  0
# =================================================================
# Total params: 814,171
# Trainable params: 814,171
# Non-trainable params: 0
# _________________________________________________________________
# Prediction took 0.9 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
autoencoder3 = DDSP_AUTOENCODER(dataset, model_dir=model_dir, restore=True)
audio, audio_gen = autoencoder2.predict(sampleNum=3)
play(audio_gen)
# Out:
# Prediction took 0.9 seconds
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
